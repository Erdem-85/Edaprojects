# %% [markdown]
# <a id="1"></a>
# # <div style="padding:20px;color:white;margin:0;font-size:100%;font-family:Verdana;text-align:center;display:fill;border-radius:15px;background-color:dodgerblue;letter-spacing:1px;overflow:hidden"><b> DAILY STOCK DATASET</b></div>
#
# <p style="text-align: center"><font color='Magenta'> <b>DS-4</b><font color='black'><p>
#
# <p style="text-align: center;"><font color='dodgerblue'> <b>Data Analytics Final Project  | May 2024</b><font color='orange'><p>

# %% [markdown]
# ## <font color=#2865c8> <b> UNDERSTANDING THE DATA </b><font color='orange'>

# %% [markdown]
# ### <font color='dodgerblue'> <b> Import The Libraries</b><font color='orange'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

  
# Enable inline plotting
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#Import the “kyphosis.csv" file using Pandas
df_prices = pd.read_csv('stocks_daily_prices.csv')
df_returns = pd.read_csv('stocks_daily_returns.csv')

# %% [markdown]
# ### <font color='dodgerblue'> <b> Perform Basic Statistical Data Analysis </b><font color='orange'>

# %% [markdown]
# <font color=dodgerblue> ✅Tasks-1 </font>
#
# - **Check out the head of the dataframe**
# - **Check out the tail of the dataframe**
# - **Check out the info of the dataframe**
# - **Check out the basic statistics of the dataframe**
# - **Check out the duplicated values of the dataframe**
# - **Check out the Missing values of the dataframe**

# %%
df_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3642 entries, 0 to 3641
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3642 non-null   object
#  1   AAPL    3642 non-null   float64
#  2   JPM     3642 non-null   float64
#  3   PG      3642 non-null   float64
#  4   UAL     3642 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 142.4+ KB

# %%
df_returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3642 entries, 0 to 3641
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3642 non-null   object
#  1   AAPL    3642 non-null   float64
#  2   JPM     3642 non-null   float64
#  3   PG      3642 non-null   float64
#  4   UAL     3642 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 142.4+ KB

# %%
df_prices.head()
# Out:
#        Date      AAPL        JPM         PG        UAL
# 0  1/2/2008  5.949703  29.448614  47.058838  29.915234
# 1  1/3/2008  5.952452  29.246094  47.058838  29.690800
# 2  1/4/2008  5.498071  28.582682  46.870098  31.000002
# 3  1/7/2008  5.424478  28.868999  47.175980  29.180000
# 4  1/8/2008  5.229351  27.723747  47.299629  24.389999

# %%
df_returns.head()
# Out:
#        Date      AAPL       JPM        PG        UAL
# 0  1/2/2008  0.000000  0.000000  0.000000   0.000000
# 1  1/3/2008  0.046203 -0.687708  0.000000  -0.750233
# 2  1/4/2008 -7.633517 -2.268378 -0.401072   4.409454
# 3  1/7/2008 -1.338518  1.001718  0.652615  -5.870973
# 4  1/8/2008 -3.597157 -3.967066  0.262103 -16.415356

# %%
df_prices.tail()
# Out:
#            Date        AAPL         JPM          PG        UAL
# 3637  6/13/2022  131.880005  115.989998  138.149994  37.020000
# 3638  6/14/2022  132.759995  114.059998  133.839996  36.990002
# 3639  6/15/2022  135.429993  115.410004  132.509995  37.889999
# 3640  6/16/2022  130.059998  113.430000  133.320007  34.779999
# 3641  6/17/2022  131.559998  113.029999  132.360001  36.279999

# %%
df_returns.tail()
# Out:
#            Date      AAPL       JPM        PG        UAL
# 3637  6/13/2022 -3.828484 -2.977838 -2.677001 -10.058308
# 3638  6/14/2022  0.667265 -1.663937 -3.119796  -0.081034
# 3639  6/15/2022  2.011147  1.183593 -0.993725   2.433084
# 3640  6/16/2022 -3.965145 -1.715625  0.611284  -8.207972
# 3641  6/17/2022  1.153314 -0.352642 -0.720077   4.312824

# %%
df_prices.describe().T
# Out:
#        count       mean        std        min        25%        50%  \
# AAPL  3642.0  39.648625  43.326924   2.387943  11.441511  23.470343
# JPM   3642.0  64.927239  39.662998  11.545819  31.298827  49.601177
# PG    3642.0  73.729653  32.623908  29.637867  46.483078  65.661438
# UAL   3642.0  43.183288  24.392486   3.130000  22.320000  43.080002
#
#             75%         max
# AAPL  45.398705  181.511704
# JPM   95.376392  169.500061
# PG    82.645994  163.410004
# UAL   60.425000   96.699997

# %%
df_returns.describe().T
# Out:
#        count      mean       std        min       25%       50%       75%  \
# AAPL  3642.0  0.105180  2.003500 -17.919513 -0.797108  0.099403  1.129585
# JPM   3642.0  0.069331  2.559122 -20.727418 -0.889705  0.017241  1.002644
# PG    3642.0  0.035579  1.198977  -8.737353 -0.482903  0.037285  0.595436
# UAL   3642.0  0.098866  4.361402 -36.770882 -1.553845  0.016636  1.636975
#
#             max
# AAPL  13.904950
# JPM   25.096737
# PG    12.009046
# UAL   68.537079

# %%
df_prices.duplicated().sum()
# Out:
# 0

# %%
df_returns.duplicated().sum()
# Out:
# 0

# %%
df_prices.isnull().sum()
# Out:
# Date    0
# AAPL    0
# JPM     0
# PG      0
# UAL     0
# dtype: int64

# %%
df_returns.isnull().sum()
# Out:
# Date    0
# AAPL    0
# JPM     0
# PG      0
# UAL     0
# dtype: int64

# %%
# Convert 'Date' column to datetime format on df_prices
df_prices['Date'] = pd.to_datetime(df_prices['Date'])

# %%
# Convert 'Date' column to datetime format on df_return
df_returns['Date'] = pd.to_datetime(df_returns['Date'])

# %%
df_prices.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3642 entries, 0 to 3641
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3642 non-null   datetime64[ns]
#  1   AAPL    3642 non-null   float64
#  2   JPM     3642 non-null   float64
#  3   PG      3642 non-null   float64
#  4   UAL     3642 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 142.4 KB

# %%
df_returns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3642 entries, 0 to 3641
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3642 non-null   datetime64[ns]
#  1   AAPL    3642 non-null   float64
#  2   JPM     3642 non-null   float64
#  3   PG      3642 non-null   float64
#  4   UAL     3642 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 142.4 KB

# %%
# Set 'Date' column as the index
df_prices.set_index('Date', inplace=True)

# %%
# Set 'Date' column as the index
df_returns.set_index('Date',inplace=True)

# %%
df_prices.head()
# Out:
#                 AAPL        JPM         PG        UAL
# Date
# 2008-01-02  5.949703  29.448614  47.058838  29.915234
# 2008-01-03  5.952452  29.246094  47.058838  29.690800
# 2008-01-04  5.498071  28.582682  46.870098  31.000002
# 2008-01-07  5.424478  28.868999  47.175980  29.180000
# 2008-01-08  5.229351  27.723747  47.299629  24.389999

# %%
df_returns.head()
# Out:
#                 AAPL       JPM        PG        UAL
# Date
# 2008-01-02  0.000000  0.000000  0.000000   0.000000
# 2008-01-03  0.046203 -0.687708  0.000000  -0.750233
# 2008-01-04 -7.633517 -2.268378 -0.401072   4.409454
# 2008-01-07 -1.338518  1.001718  0.652615  -5.870973
# 2008-01-08 -3.597157 -3.967066  0.262103 -16.415356

# %% [markdown]
# ##  <font color=#2865c8> <b> DATA VISUALIZATION </b><font color='black'>

# %% [markdown]
# <font color=dodgerblue> ✅Tasks-2 </font>
#
# 3. Using Matplotlib, plot lineplots that display all 4 stocks daily prices on one single figure.
# 4. Using Matplotlib, plot 4 stocks daily prices on multiple subplots.
# 5. Using Matplotlib, plot the 4 plots on subplots next to each other (all figures in one row).
# 6. Using Matplotlib, plot the scatterplot between Apple and JP Morgan daily returns.
# 7. Using Seaborn, plot a similar scatterplot between Apple and JP Morgan daily returns.
#
# 8. Using Matplotlib, plot a pie chart that shows asset allocations, using the 'explode' attribute to increase the separation between AAPL and the rest of the portfolio.
#
# 9. Assume that you decided to become bullish on AAPL and you allocated 70% of your assets in it. You also decided to equally divide the rest of your assets in other stocks (JPM, PG, and UAL). Using Matplotlib, plot a pie chart that shows these allocations. Use 'explode’ attribute to increase the separation between AAPL and the rest of the portfolio.
#
# 10. Using Matplotlib, plot the histogram for United Airlines and P&G returns using 40 bins with red color. Display the mean and standard deviation for both stocks on top of the figure.

# %% [markdown]
# ### <font color='dodgerblue'> <b> Line plots </b><font color='orange'>

# %%
#3) Using Matplotlib, plot lineplots that display all 4 stocks daily prices on one single figure.

# Plotting the daily prices of the four stocks
plt.figure(figsize=(14, 7))
    
# 1.yol: Plot each stock's daily price 
plt.plot(df_prices.index, df_prices['AAPL'], label='AAPL')
plt.plot(df_prices.index, df_prices['JPM'], label='JPM')
plt.plot(df_prices.index, df_prices['PG'], label='PG')
plt.plot(df_prices.index, df_prices['UAL'], label='UAL')

# 2.yol: Plot each stock's daily price 
# for column in df_prices.columns:
#     plt.plot(df_prices.index, df_prices[column], label=column)

# Add title and labels
plt.title('Daily Prices of AAPL, JPM, PG, and UAL')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.grid(True)

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <font color=dodgerblue> 💡 Output: Line plots that display all 4 stocks daily prices</font>
#
# - Bu grafikte df_prices veri çerçevesindeki dört hisse senedinin günlük fiyatlarını tek bir grafikte gösterilmistir.
# - Veri setindeki trendleri, desenleri ve olası anormallikleri görselleştirmenin etkilidir.

# %% [markdown]
# ### <font color='dodgerblue'> <b> Subplot with Line plots </b><font color='orange'>

# %%
# 4. Using Matplotlib, plot 4 stocks daily prices on multiple subplots.
# Create a figure and a set of subplots
fig, ax = plt.subplots(nrows=4, ncols=1, figsize=(14, 14), sharex=True)

# 1.yol: Plot each stock's daily price on separate subplots

# AAPL
ax[0].plot(df_prices.index, df_prices['AAPL'], label='AAPL')
ax[0].set_title('Daily Prices of AAPL')
ax[0].set_ylabel('Price')
ax[0].legend()
ax[0].grid(True)

# JPM
ax[1].plot(df_prices.index, df_prices['JPM'], label='JPM')
ax[1].set_title('Daily Prices of JPM')
ax[1].set_ylabel('Price')
ax[1].legend()
ax[1].grid(True)

# PG
ax[2].plot(df_prices.index, df_prices['PG'], label='PG')
ax[2].set_title('Daily Prices of PG')
ax[2].set_ylabel('Price')
ax[2].legend()
ax[2].grid(True)

# UAL
ax[3].plot(df_prices.index, df_prices['UAL'], label='UAL')
ax[3].set_title('Daily Prices of UAL')
ax[3].set_ylabel('Price')
ax[3].legend()
ax[3].grid(True)

#2.yol: Plot each stock's daily price on separate subplots
# for i, column in enumerate(df_prices.columns):
#     axes[i].plot(df_prices.index, df_prices[column], label=column)
#     axes[i].set_title(f'Daily Prices of {column}')
#     axes[i].set_ylabel('Price')
#     axes[i].legend()
#     axes[i].grid(True)

# Add a common x-axis label
plt.xlabel('Date')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %%
# 5. Using Matplotlib, plot the 4 plots on subplots next to each other (all figures in one row).

# Create a figure and a set of subplots
fig, ax = plt.subplots(nrows=1, ncols=4, figsize=(20, 5), sharex=True)

# Plot each stock's daily price on separate subplots

# AAPL
ax[0].plot(df_prices.index, df_prices['AAPL'], label='AAPL')
ax[0].set_title('Daily Prices of AAPL')
ax[0].set_ylabel('Price')
ax[0].legend()
ax[0].grid(True)

# JPM
ax[1].plot(df_prices.index, df_prices['JPM'], label='JPM')
ax[1].set_title('Daily Prices of JPM')
ax[1].set_ylabel('Price')
ax[1].legend()
ax[1].grid(True)

# PG
ax[2].plot(df_prices.index, df_prices['PG'], label='PG')
ax[2].set_title('Daily Prices of PG')
ax[2].set_ylabel('Price')
ax[2].legend()
ax[2].grid(True)

# UAL
ax[3].plot(df_prices.index, df_prices['UAL'], label='UAL')
ax[3].set_title('Daily Prices of UAL')
ax[3].set_ylabel('Price')
ax[3].legend()
ax[3].grid(True)

# Add a common x-axis label
fig.text(0.5, 0.04, 'Date', ha='center')

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <font color=dodgerblue> 💡 Output: lineplots that display all 4 stocks daily prices</font>
#
# - Bu grafikte df_prices veri çerçevesindeki dört hisse senedinin günlük fiyatlarını gösterilmistir.
# - Veri setindeki trendlerin, desenlerin ve olası anormalliklerin görselleştirmesi hedeflenmistir.
#
# ---
#
# Bu grafikte COVID-19 pandemisi dönemine denk gelen alan, özellikle 2020 yılı başlarında hisse senedi fiyatlarında belirgin bir düşüşün olduğu zaman dilimidir.
#
# Pandemi dönemine ait bazı önemli gözlemler şunlardır:
#
# 1. **Apple (AAPL):**
#    - 2020 yılının başlarında Apple'ın hisse fiyatında ani bir düşüş görülüyor. Pandemi sırasında tedarik zincirinde yaşanan aksaklıklar ve talep belirsizlikleri Apple'ın hisse senedi fiyatını olumsuz etkiledi. Ancak, daha sonra hisse fiyatı toparlanmış ve pandeminin ilerleyen dönemlerinde güçlü bir büyüme göstermiştir.
#
# 2. **JP Morgan (JPM):**
#    - JP Morgan'ın hisse senedi fiyatı da 2020'nin başlarında keskin bir şekilde düşmüş. Finans sektörü, ekonomik belirsizlikler ve düşük faiz oranları nedeniyle pandemiden olumsuz etkilendi. Ancak, daha sonra hisse fiyatı kademeli olarak toparlanmaya başlamıştır.
#
# 3. **Procter & Gamble (PG):**
#    - P&G'nin hisse senedi fiyatında da 2020'nin başlarında bir düşüş görülmekle birlikte, diğer hisse senetlerine göre daha az belirgin. P&G, tüketici ürünleri sektöründe faaliyet gösterdiğinden, pandemi sırasında temizlik ve hijyen ürünlerine olan talebin artmasıyla daha dirençli olmuştur.
#
# 4. **United Airlines (UAL):**
#    - United Airlines'ın hisse senedi fiyatı, 2020'nin başlarında büyük bir düşüş yaşamıştır. Havacılık sektörü, seyahat kısıtlamaları ve azalan yolcu talebi nedeniyle pandemiden en çok etkilenen sektörlerden biri olmuştur. UAL'nin hisse fiyatı, 2020 boyunca düşük seviyelerde kalmış ve toparlanma süreci diğer sektörlere göre daha yavaş olmuştur.
#
# **Genel İçgörüler:**
#
# - **Volatilite Artışı:** Pandemi döneminde tüm hisse senetlerinde belirgin bir volatilite artışı gözlemlenmiştir. Piyasalarda yaşanan belirsizlikler ve ani değişiklikler, hisse senedi fiyatlarının dalgalanmasına neden olmuştur.
# - **Sektörel Farklılıklar:** Farklı sektörlerdeki şirketler, pandemiden farklı derecelerde etkilenmiştir. Teknoloji ve tüketici ürünleri sektörleri daha hızlı toparlanırken, havacılık ve finans sektörleri daha uzun süreli etkiler yaşamıştır.
# - **Uzun Vadeli Toparlanma:** 2020'de yaşanan ani düşüşlerden sonra, bazı hisse senetleri (özellikle Apple) pandemi sonrası dönemde güçlü bir toparlanma göstermiştir.
#
# Bu içgörüler, pandeminin şirketler üzerindeki finansal etkilerini ve piyasa dinamiklerini anlamak için önemlidir.

# %% [markdown]
# ### <font color='dodgerblue'> <b> Scatter Plot</b><font color='orange'>

# %%
# 6. Using Matplotlib, plot the scatterplot between Apple and JP Morgan daily returns.

# Plot the scatter plot between Apple and JP Morgan daily returns
plt.figure(figsize=(10, 6))

plt.scatter(df_returns['AAPL'], df_returns['JPM'], c='blue', alpha=0.5, label='Apple')
plt.scatter(df_returns['JPM'], df_returns['AAPL'], c='brown', alpha=0.5, label='JP Morgan')

plt.title('Scatter Plot between Apple and JP Morgan Daily Returns')
plt.xlabel('Apple Daily Returns')
plt.ylabel('JP Morgan Daily Returns')
plt.grid(True)

# %% [markdown]
# <font color='dodgerblue'> <b> Bonus: Scatter Plot</b><font color='orange'>

# %%
import pandas as pd
import plotly.express as px

# Veri setini yeniden yükleyelim
returns_df = pd.read_csv('stocks_daily_returns.csv')
returns_df['Date'] = pd.to_datetime(returns_df['Date'])
returns_df.set_index('Date', inplace=True)

# Create a DataFrame for plotting with plotly
plot_df = returns_df.reset_index()

# Add formatted date column for hover data
plot_df['Formatted Date'] = plot_df['Date'].dt.strftime('%Y-%m-%d')

# Create the figure
fig = go.Figure()

# Add Apple scatter plot
fig.add_trace(go.Scatter(
    x=plot_df['AAPL'],
    y=plot_df['JPM'],
    mode='markers',
    marker=dict(color='blue', size=5),
    text=plot_df['Formatted Date'],
    name='Apple',
    hovertemplate='Date: %{text}<br>Apple Returns: %{x}<br>'
))

# Add JP Morgan scatter plot
fig.add_trace(go.Scatter(
    x=plot_df['JPM'],
    y=plot_df['AAPL'],
    mode='markers',
    marker=dict(color='saddlebrown', size=5),
    text=plot_df['Formatted Date'],
    name='JP Morgan',
    hovertemplate='Date: %{text}<br>JP Morgan Returns: %{x}<br>'
))

# Set the titles and labels
fig.update_layout(
    title='Scatterplot of Daily Returns: Apple vs. JP Morgan',
    xaxis_title='Apple Daily Returns',
    yaxis_title='JP Morgan Daily Returns',
    hovermode='closest'
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="96f2c99b-4140-4378-9e2e-ce9943045382" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96f2c99b-4140-4378-9e2e-ce9943045382")) {                    Plotly.newPlot(                        "96f2c99b-4140-4378-9e2e-ce9943045382",                        [{"hovertemplate":"Date: %{text}<br>Apple Returns: %{x}<br>","marker":{"color":"blue","size":5},"mode":"markers","name":"Apple","text":["2008-01-02","2008-01-03","2008-01-04","2008-01-07","2008-01-08","2008-01-09","2008-01-10","2008-01-11","2008-01-14","2008-01-15","2008-01-16","2008-01-17","2008-01-18","2008-01-22","2008-01-23","2008-01-24","2008-01-25","2008-01-28","2008-01-29","2008-01-30","2008-01-31","2008-02-01","2008-02-04","2008-02-05","2008-02-06","2008-0
# ...

# %%
#7) Using Seaborn, plot a similar scatterplot between Apple and JP Morgan daily returns.

# Create a scatter plot using Seaborn
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df_returns['AAPL'], y=df_returns['JPM'], alpha=0.5)
plt.title('Scatter Plot between Apple and JP Morgan Daily Returns')
plt.xlabel('Apple Daily Returns')
plt.ylabel('JP Morgan Daily Returns')
plt.grid(True)

# Save the plot as an image file
plt.savefig('seaborn_scatter_plot.png', dpi=300)

# Show plot
plt.show()

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <font color=dodgerblue> 💡 Output: Scatter Plot</font>
#
# Bu scatter plot, Apple (AAPL) ve JP Morgan (JPM) günlük getirileri arasındaki ilişkiyi göstermektedir. Her bir nokta, belirli bir gün için Apple ve JP Morgan'ın günlük getirilerini temsil eder.
#
# - **Korelasyon:** Apple ve JP Morgan günlük getirileri arasında pozitif bir korelasyon bulunmaktadır. Bu, genellikle bir hisse senedinin getirisi arttığında diğerinin de artma eğiliminde olduğu anlamına gelir.
# - **Volatilite:** Her iki hisse senedi de düşük volatiliteye sahiptir, ancak bazı günlerde önemli sapmalar görülebilir.
# - **Aykırı Değerler:** Belirli günlerde her iki hisse senedi de olağan dışı getiriler yaşamıştır, bu da piyasa olayları veya haberler gibi dış faktörlere bağlanabilir.
#
# Bu analiz, yatırımcıların Apple ve JP Morgan hisselerinin getirileri arasındaki ilişkiyi anlamalarına ve portföylerini çeşitlendirme stratejilerini belirlemelerine yardımcı olabilir.

# %% [markdown]
# ### <font color='dodgerblue'> <b>Pie Chart</b><font color='orange'>

# %%
# 8) Using Matplotlib, plot a pie chart that shows asset allocations, using the 'explode' attribute to 
#increase the separation between AAPL and the rest of the portfolio.

# Define the asset allocations
allocations = [40, 25, 20, 15]  # Example percentages for AAPL, JPM, PG, UAL
labels = ['AAPL', 'JPM', 'PG', 'UAL']

# Define the explode parameter to separate AAPL from the rest
explode = [0.1, 0, 0, 0]

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(allocations, labels=labels, explode=explode, autopct='%1.1f%%', shadow=True, startangle=140, colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])
plt.title('Asset Allocations')
plt.show()

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <font color=dodgerblue> 💡 Output: Pie Chart</font>
#
# Bu pasta grafiği, belirli varlıkların portföy içindeki dağılımını göstermektedir. Grafik, her bir varlığın portföydeki yüzdesini renkli dilimlerle temsil eder. Apple (AAPL) dilimi diğerlerinden ayrılmıştır ve daha belirgin hale getirilmiştir.
#
#
# - **Dengeli Portföy:** Grafik, yatırımcının portföyünü çeşitlendirdiğini ve farklı sektörlerden şirketlere yatırım yaptığını gösterir. AAPL'ye yüksek ağırlık verilmiş olsa da, JPM, PG ve UAL ile risk dağıtılmıştır.
# - **Risk Yönetimi:** AAPL'nin portföydeki büyük payı, yatırımcının teknoloji sektörüne olan güvenini gösterirken, diğer varlıkların daha küçük payları, potansiyel risklerin yönetildiğini ve farklı sektörlere yayıldığını gösterir.
# - **Sektörel Dağılım:** Portföyde teknoloji (AAPL), finans (JPM), tüketim ürünleri (PG) ve havacılık (UAL) sektörlerinden varlıklar bulunmaktadır. Bu çeşitlendirme, sektörel risklerin dengelenmesine yardımcı olabilir.
#
# *Bu pasta grafiği, yatırımcının portföydeki varlık dağılımını ve stratejik tercihini açıkça ortaya koyar. AAPL'nin portföydeki baskın rolü, yatırımcının bu varlığa olan güvenini ve beklentilerini yansıtırken, diğer varlıkların daha küçük payları, portföyün çeşitlendirilmiş ve risklerin dağıtılmış olduğunu gösterir.*

# %%
# 9. Assume that you decided to become bullish on AAPL and you allocated 70% of your assets in it. 
# You also decided to equally divide the rest of your assets in other stocks (JPM, PG, and UAL). 
# Using Matplotlib, plot a pie chart that shows these allocations. 
# Use 'explode’ attribute to increase the separation between AAPL and the rest of the portfolio.

# Define the new asset allocations
allocations = [70, 10, 10, 10]  # New percentages for AAPL, JPM, PG, UAL
labels = ['AAPL', 'JPM', 'PG', 'UAL']

# Define the explode parameter to separate AAPL from the rest
explode = [0.1, 0, 0, 0]

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(allocations, labels=labels, explode=explode, autopct='%1.1f%%', shadow=True, startangle=140,colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])
plt.title('New Asset Allocations')
plt.show()

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <font color=dodgerblue> 💡 Output: Pie Chart</font>
#
# Bu yeni pasta grafiği, varlık dağılımlarının güncellenmiş bir versiyonunu göstermektedir. Apple (AAPL) hala portföyün en büyük dilimini oluştururken, JP Morgan (JPM), Procter & Gamble (PG) ve United Airlines (UAL) eşit olarak kalan kısmı paylaşmaktadır.
#
# - **Teknolojiye Güven:** Apple'ın portföydeki %70'lik payı, yatırımcının teknoloji sektörüne olan güvenini ve özellikle Apple'ın gelecekteki büyüme potansiyeline olan inancını yansıtır.
# - **Çeşitlendirme:** Kalan %30'un eşit olarak JPM, PG ve UAL arasında dağıtılması, yatırımcının finans, tüketici ürünleri ve havacılık sektörlerine de maruz kalmak istediğini gösterir. Bu çeşitlendirme, portföyün toplam riskini azaltmaya yardımcı olabilir.
# - **Risk Yönetimi:** Apple'ın büyük payı nedeniyle, portföy büyük ölçüde Apple'ın performansına bağımlıdır. Ancak, JPM, PG ve UAL'nin varlığı, potansiyel risklerin dağıtılmasını sağlar.
#
# *Bu pasta grafiği, yatırımcının portföy stratejisini ve varlık dağılımını açıkça ortaya koyar. Apple'a yapılan yüksek yatırım, yatırımcının bu şirkete olan güvenini gösterirken, diğer varlıklara yapılan yatırımlar, çeşitlendirme yoluyla risk yönetimini hedeflemektedir. Bu strateji, potansiyel kazançları maksimize ederken, aynı zamanda belirli risklerin dağıtılmasını sağlar.*

# %% [markdown]
# ### <font color='dodgerblue'> <b> Histogram Graph</b><font color='orange'>

# %%
# 10. Using Matplotlib, plot the histogram for United Airlines and P&G returns using 40 bins with red color. 
# Display the mean and standard deviation for both stocks on top of the figure.

# Calculate the mean and standard deviation for UAL and PG returns
ual_mean = df_returns['UAL'].mean()
ual_std = df_returns['UAL'].std()
pg_mean = df_returns['PG'].mean()
pg_std = df_returns['PG'].std()

# Plot the histograms for UAL and PG returns
plt.figure(figsize=(10, 5))

# Histogram for UAL
plt.subplot(1, 2, 1)
plt.hist(df_returns['UAL'], bins=40, color='red', alpha=0.7)
plt.title(f'UAL Returns\nMean: {ual_mean:.2f}, Std: {ual_std:.2f}')
plt.xlabel('Returns')
plt.ylabel('Frequency')
plt.grid(True)

# Histogram for PG
plt.subplot(1, 2, 2)
plt.hist(df_returns['PG'], bins=40, color='red', alpha=0.7)
plt.title(f'PG Returns\nMean: {pg_mean:.2f}, Std: {pg_std:.2f}')
plt.xlabel('Returns')
plt.ylabel('Frequency')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <font color=dodgerblue> 💡 Output: Histogram</font>
#
# - Bu grafik, United Airlines (UAL) ve Procter & Gamble (PG) günlük getirilerinin histogramlarını göstermektedir.
# - Her iki histogram da günlük getirilerin dağılımını görselleştirir ve üst kısımda her hisse senedinin ortalama (mean) ve standart sapma (standard deviation) değerleri belirtilmiştir.
#
# **Grafiğin Yorumlanması**
#
# 1. **United Airlines (UAL) Getirileri:**
#    - **Ortalama (Mean):** 0.10
#    - **Standart Sapma (Std):** 4.36
#    - Histogram, UAL'nin günlük getirilerinin çoğunlukla 0 civarında yoğunlaştığını göstermektedir. Bu, UAL'nin getirilerinin genellikle küçük ve pozitif olduğunu, ancak belirli günlerde yüksek volatilite yaşandığını gösterir.
#    - Yüksek standart sapma (4.36), UAL'nin getirilerinin oldukça değişken olduğunu ve bazı günlerde büyük dalgalanmalar yaşadığını gösterir.
#    - Histogramın geniş bir dağılıma sahip olması, bazı günlerde oldukça büyük pozitif veya negatif getirilerin yaşandığını gösterir.
#
# 2. **Procter & Gamble (PG) Getirileri:**
#    - **Ortalama (Mean):** 0.04
#    - **Standart Sapma (Std):** 1.20
#    - PG'nin histogramı, getirilerin büyük çoğunluğunun 0 civarında yoğunlaştığını göstermektedir. Bu, PG'nin getirilerinin genel olarak küçük ve sabit olduğunu, büyük dalgalanmaların nadir olduğunu gösterir.
#    - Daha düşük standart sapma (1.20), PG'nin getirilerinin UAL'ye kıyasla daha az değişken olduğunu ve daha istikrarlı bir performans sergilediğini gösterir.
#    - Histogramın dar bir dağılıma sahip olması, PG'nin günlük getirilerinin büyük ölçüde 0'a yakın olduğunu ve büyük sapmaların nadiren yaşandığını gösterir.
#
# **Genel İçgörüler:**
#
# - **Volatilite Farkı:** UAL'nin getirileri, PG'nin getirilerine kıyasla çok daha değişken. UAL'nin yüksek standart sapması, havacılık sektörünün genellikle daha volatil olduğunun bir göstergesidir. Öte yandan, PG'nin düşük standart sapması, tüketici ürünleri sektörünün daha istikrarlı olduğunu gösterir.
# - **Getiri Dağılımı:** Her iki hisse senedi de ortalamada pozitif getiriler sağlamaktadır, ancak UAL'nin getirileri daha geniş bir aralıkta dağılım göstermektedir. PG'nin getirileri ise daha dar bir aralıkta yoğunlaşmıştır.
# - **Risk ve Getiri:** UAL, yüksek volatilitesi nedeniyle daha yüksek risk taşırken, potansiyel olarak daha yüksek getiri sunabilir. PG ise daha düşük volatilite ile daha istikrarlı ve düşük riskli bir yatırım olarak değerlendirilebilir.
#
# Bu analiz, yatırımcıların UAL ve PG hisselerinin getirilerini ve risk profilini anlamalarına yardımcı olabilir. Volatilite ve ortalama getiriler, yatırım kararlarında önemli bir rol oynar ve portföy çeşitlendirme stratejilerinin belirlenmesine katkı sağlar.

# %% [markdown]
# ##  <font color=#2865c8> <b> CORRELATIONS AND RELATIONSHIPS </b><font color='black'>

# %% [markdown]
# ### <font color='dodgerblue'> <b> Heatmap</b><font color='orange'>

# %% [markdown]
# <font color=dodgerblue> ✅Tasks-3 </font>
#
# 11. Using Seaborn, plot a heatmap that shows the correlations between stocks daily returns. Comment on the correlation between UAL and P&G.

# %%
# Calculate the correlation matrix
correlation_matrix = df_returns.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix of Stocks Daily Returns')
plt.show()

# Comment on the correlation between UAL and PG
ual_pg_correlation = correlation_matrix.loc['UAL', 'PG']
print(f'The correlation between UAL and PG is: {ual_pg_correlation:.4f}')
# Out:
# The correlation between UAL and PG is: 0.2382

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <font color=dodgerblue> 💡 Output: Heatmap</font>
#
# - Bu korelasyon matrisi, Apple (AAPL), JP Morgan (JPM), Procter & Gamble (PG) ve United Airlines (UAL) günlük getirileri arasındaki ilişkileri görselleştirir.
# - Her bir hücredeki değer, iki hisse senedi getirisi arasındaki korelasyon katsayısını temsil eder ve renk skalası, korelasyonun yönünü ve gücünü belirtir.
#
# **Grafiğin Yorumlanması**
#
# 1. **Apple (AAPL) ve Diğerleri:**
#    - AAPL ve JPM arasında pozitif bir korelasyon var (0.44). Bu, AAPL ve JPM getirilerinin genellikle birlikte hareket ettiğini gösterir.
#    - AAPL ve PG arasında daha düşük bir pozitif korelasyon var (0.37). Bu, AAPL ve PG getirilerinin genellikle birlikte hareket ettiğini, ancak ilişki gücünün daha zayıf olduğunu gösterir.
#    - AAPL ve UAL arasında en düşük pozitif korelasyon var (0.29). Bu, AAPL ve UAL getirilerinin birlikte hareket etme eğiliminde olduğunu, ancak bu ilişkinin oldukça zayıf olduğunu gösterir.
#
# 2. **JP Morgan (JPM) ve Diğerleri:**
#    - JPM ve PG arasında orta düzeyde pozitif bir korelasyon var (0.41). Bu, JPM ve PG getirilerinin birlikte hareket etme eğiliminde olduğunu gösterir.
#    - JPM ve UAL arasında en yüksek pozitif korelasyon var (0.47). Bu, JPM ve UAL getirilerinin birlikte hareket etme eğiliminde olduğunu ve aralarındaki ilişkinin diğerlerine göre daha güçlü olduğunu gösterir.
#
# 3. **Procter & Gamble (PG) ve United Airlines (UAL):**
#    - PG ve UAL arasında en düşük pozitif korelasyon var (0.24). Bu, PG ve UAL getirilerinin birlikte hareket etme eğiliminde olduğunu, ancak bu ilişkinin oldukça zayıf olduğunu gösterir.
#
# **Genel Cikarim**
# - **Pozitif Korelasyon:** Tüm hisse senetleri arasında pozitif korelasyonlar vardır, yani getirileri genellikle aynı yönde hareket etme eğilimindedir. Ancak, korelasyonların güçleri değişkenlik göstermektedir.
# - **Yüksek Korelasyon:** JPM ve UAL arasındaki en yüksek pozitif korelasyon (0.47), bu iki hisse senedinin getirilerinin benzer piyasa koşullarına tepki verme eğiliminde olduğunu gösterir.
# - **Düşük Korelasyon:** PG ve UAL arasındaki en düşük pozitif korelasyon (0.24), bu iki hisse senedinin getirilerinin büyük ölçüde bağımsız olduğunu ve birlikte hareket etme eğiliminde olmadığını gösterir.
#
# **Sonuç:**
# Bu korelasyon matrisi, portföy çeşitlendirmesi için önemli bilgiler sağlar. Yatırımcılar, yüksek korelasyona sahip varlıkları birlikte tutarak risklerini optimize edebilirler. Öte yandan, düşük korelasyona sahip varlıkları portföylerine ekleyerek toplam risklerini azaltabilirler. UAL ve PG arasındaki düşük korelasyon, bu iki varlığın portföyde çeşitlendirme amacıyla birlikte kullanılabileceğini göstermektedir.

# %% [markdown]
# ##  <font color=#2865c8> <b> TRENDS, PATTERNS and ANOMALIES </b><font color='black'>

# %% [markdown]
# ### <font color='dodgerblue'> <b> 3D Plot</b><font color='orange'>

# %% [markdown]
# <font color=dodgerblue> ✅Tasks-4 </font>
#
# 12. Plot a 3D plot showing all daily returns from JPM, AAPL, and UAL.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Load the datasets
df_returns = pd.read_csv('stocks_daily_returns.csv')

# Convert 'Date' column to datetime format
df_returns['Date'] = pd.to_datetime(df_returns['Date'])

# Set 'Date' column as the index (optional)
df_returns.set_index('Date', inplace=True)

# Extracting the relevant data
jpm_returns = df_returns['JPM']
aapl_returns = df_returns['AAPL']
ual_returns = df_returns['UAL']

# Enable interactive plots
# %matplotlib notebook

# Create a 3D plot
fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')

# Plot the data
ax.scatter(jpm_returns, aapl_returns, ual_returns, c='r', marker='o', alpha=0.6)

# Add labels
ax.set_xlabel('JP Morgan Daily Returns')
ax.set_ylabel('Apple Daily Returns')
ax.set_zlabel('United Airlines Daily Returns')
ax.set_title('3D Plot of Daily Returns: JPM, AAPL, and UAL')

# Show the plot
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="999.9999602635718">

# %% [markdown]
# <font color='dodgerblue'> <b> Bonus: 3D Plot</b><font color='orange'>

# %%
import pandas as pd
import plotly.graph_objects as go

# Veri setini yeniden yükleyelim
returns_df = pd.read_csv('stocks_daily_returns.csv')
returns_df['Date'] = pd.to_datetime(returns_df['Date'])
returns_df.set_index('Date', inplace=True)

# Create a DataFrame for plotting with plotly
plot_df = returns_df.reset_index()

# Create the figure
fig = go.Figure()

# Add JPM scatter plot
fig.add_trace(go.Scatter3d(
    x=plot_df['Date'],
    y=plot_df['JPM'],
    z=plot_df['UAL'],
    mode='markers',
    marker=dict(color='blue', size=5),
    text=plot_df['Date'].dt.strftime('%Y-%m-%d'),
    name='JPM'
))

# Add AAPL scatter plot
fig.add_trace(go.Scatter3d(
    x=plot_df['Date'],
    y=plot_df['AAPL'],
    z=plot_df['UAL'],
    mode='markers',
    marker=dict(color='red', size=5),
    text=plot_df['Date'].dt.strftime('%Y-%m-%d'),
    name='AAPL'
))

# Add UAL scatter plot
fig.add_trace(go.Scatter3d(
    x=plot_df['Date'],
    y=plot_df['AAPL'],
    z=plot_df['JPM'],
    mode='markers',
    marker=dict(color='green', size=5),
    text=plot_df['Date'].dt.strftime('%Y-%m-%d'),
    name='UAL'
))

# Set the titles and labels
fig.update_layout(
    title='3D Plot of Daily Returns: JPM, AAPL, and UAL',
    scene=dict(
        xaxis_title='Date',
        yaxis_title='Daily Returns',
        zaxis_title='Daily Returns'
    )
)

# Show the plot
fig.show()
# Out:
# <div>                            <div id="a8bf7e68-66f9-4c66-8244-0dd7b430603e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a8bf7e68-66f9-4c66-8244-0dd7b430603e")) {                    Plotly.newPlot(                        "a8bf7e68-66f9-4c66-8244-0dd7b430603e",                        [{"marker":{"color":"blue","size":5},"mode":"markers","name":"JPM","text":["2008-01-02","2008-01-03","2008-01-04","2008-01-07","2008-01-08","2008-01-09","2008-01-10","2008-01-11","2008-01-14","2008-01-15","2008-01-16","2008-01-17","2008-01-18","2008-01-22","2008-01-23","2008-01-24","2008-01-25","2008-01-28","2008-01-29","2008-01-30","2008-01-31","2008-02-01","2008-02-04","2008-02-05","2008-02-06","2008-02-07","2008-02-08","2008-02-11","2008-02-12","2008-02-13","20
# ...

# %% [markdown]
# <div style="border-radius:10px;border:#254E58 solid;padding: 15px;background-color:white;font-size:110%;text-align:left">
#
# <font color=dodgerblue> 💡 Output: 3D Plot</font>
#
# - Bu 3D scatter plot, JP Morgan (JPM), Apple (AAPL) ve United Airlines (UAL) günlük getirilerini üç boyutlu bir perspektifte gösterir. Grafik, bu üç hisse senedinin günlük getirileri arasındaki ilişkileri görselleştirmeye yardımcı olur.
#
# **Grafiğin Yorumlanması**
#
# 1. **Merkezi Yoğunluk:**
#    - Noktaların büyük çoğunluğu merkeze yakın yoğunlaşmış durumda. Bu, JPM, AAPL ve UAL'nin getirilerinin genellikle küçük değerler etrafında toplandığını gösterir.
#
# 2. **Dağılım:**
#    - Grafikteki yayılma, hisse senetlerinin getirilerinin geniş bir aralıkta değişebileceğini gösterir.
#    - Her üç eksende de büyük sapmalar görülebilir, bu da belirli günlerde hisse senetlerinde büyük dalgalanmaların yaşandığını gösterir.
#
# 3. **Aykırı Değerler:**
#    - Grafik, her üç eksende de bazı aykırı değerler içerir. Bu noktalar, ilgili hisse senedinde olağan dışı yüksek veya düşük getirileri temsil eder.
#
# **Genel Cikarim**
#
# - **Volatilite:** UAL, JPM ve AAPL'nin getirileri arasında belirgin bir volatilite farkı olabilir. UAL'nin ekseninde daha geniş bir yayılma gözleniyor, bu da UAL'nin getirilerinin daha değişken olduğunu gösterir.
# - **Korelasyon:** Noktaların genellikle merkezde yoğunlaşması, bu üç hisse senedinin getirilerinin birbiriyle ilişkisinin bulunduğunu gösterir.
# - **Aykırı Değerler:** Özellikle uç noktalarda görülen bazı noktalar, piyasada veya belirli hisse senedinde meydana gelen ani değişimlerin göstergesi olabilir.
#
# **Sonuc**
#
# Bu 3D scatter plot, yatırımcıların JPM, AAPL ve UAL hisse senetlerinin günlük getirileri arasındaki ilişkiyi anlamalarına yardımcı olabilir. Getirilerin merkezde yoğunlaşması ve geniş yayılım, bu hisse senetlerinin volatilitesini ve potansiyel risklerini göstermektedir. Aykırı değerlerin varlığı, yatırım kararları alırken dikkate alınması gereken önemli piyasa olaylarını veya haberleri işaret edebilir.
